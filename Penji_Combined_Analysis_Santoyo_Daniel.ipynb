# %%
#Importing Pandas
import pandas as pd

#Reading CSV files
Checkins = pd.read_csv("check_ins.csv")
Sessions = pd.read_csv("sessions.csv")

# %%
# Data manipulation

# Field names changed to be more descriptive
Checkins.rename(columns = {'Kind':'Session Type','Location':'Community'}, inplace = True)
Sessions.rename(columns = {'Kind':'Session Type','Location':'Community'}, inplace = True)

#Adding Kind field as "Drop-In Tutoring" to describe all data records
Checkins['Session Type'] = 'Drop-In Tutoring'

# Adding Month and Year data fields to extract specific date data
Sessions['Started_At_Year'] = pd.DatetimeIndex(Sessions['Started At Date']).year
Sessions['Started_At_Month'] = pd.DatetimeIndex(Sessions['Started At Date']).month
Checkins['Started_At_Year'] = pd.DatetimeIndex(Checkins['Started At Date']).year
Checkins['Started_At_Month'] = pd.DatetimeIndex(Checkins['Started At Date']).month

# %%
# Creating Union between sessions.csv and check_ins.csv

#Creating smaller tables with extracted date parts
Checkins_Date_df = Checkins[["Check In At Date","Community","Status", "Session Type", "Course", "Student Email","Student Name","Started At Date", "Started At Time", "Ended At Date", "Ended At Time", "Duration Minutes","Started_At_Year","Started_At_Month"]]
Sessions_Date_df = Sessions[["Requested At Date","Community","Status", "Session Type", "Course", "Student Email","Student Name","Started At Date", "Started At Time", "Ended At Date", "Ended At Time", "Tutor Submitted Length","Started_At_Year","Started_At_Month"]]

#Defining tables to preform concat function
Date_df1 = Checkins_Date_df[["Community","Status", "Session Type", "Course", "Student Email","Student Name","Started At Date", "Started At Time", "Ended At Date", "Ended At Time", "Started_At_Year","Started_At_Month"]]
Date_df2 = Sessions_Date_df[["Community","Status", "Session Type", "Course", "Student Email","Student Name","Started At Date", "Started At Time", "Ended At Date", "Ended At Time", "Started_At_Year","Started_At_Month"]]

#Union between Date_df1 and Date_df2
All_Dates_df = pd.concat([Date_df1,Date_df2], ignore_index = True)

# %%
# First df - Top 10 count of total Tutoting sessions by community 

#Calculating count of tutoring sessions by Community
All_Cnt_Com = All_Dates_df.groupby(["Community"])["Community"].count().reset_index(name="Total Tutoring Sessions").sort_values(by='Total Tutoring Sessions', ascending=False).reset_index(drop=True)

#Calculating percent of total for Session Count by Community
All_Cnt_Com['Session_Pct'] = ((All_Cnt_Com['Total Tutoring Sessions']/All_Cnt_Com['Total Tutoring Sessions'].sum())*100).round(0)

#Formatting All_Cnt_Com
All_Cnt_Com = All_Cnt_Com.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

#Top 10 Communities by count of tutoring sessions W/ % of total
All_Cnt_Com
# Out:
# <style type="text/css">
# #T_13680 th {
#   text-align: left;
# }
# #T_13680_row0_col0, #T_13680_row0_col1, #T_13680_row0_col2, #T_13680_row1_col0, #T_13680_row1_col1, #T_13680_row1_col2, #T_13680_row2_col0, #T_13680_row2_col1, #T_13680_row2_col2, #T_13680_row3_col0, #T_13680_row3_col1, #T_13680_row3_col2, #T_13680_row4_col0, #T_13680_row4_col1, #T_13680_row4_col2, #T_13680_row5_col0, #T_13680_row5_col1, #T_13680_row5_col2, #T_13680_row6_col0, #T_13680_row6_col1, #T_13680_row6_col2, #T_13680_row7_col0, #T_13680_row7_col1, #T_13680_row7_col2, #T_13680_row8_col0, #T_13680_row8_col1, #T_13680_row8_col2, #T_13680_row9_col0, #T_13680_row9_col1, #T_13680_row9_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_13680">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13680_level0_col0" class="col_heading level0 col0" >Community</th>
#       <th id="T_13680_level0_col1" class="col_heading level0 col1" >Total Tutoring Sessions</th>
#       <th id="T_13680_level0_col2" class="col_heading level0 col2" >Session_Pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13680_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13680_row0_col0" class="data row0 col0" >Zoom Meeting - Online</td>
#       <td id="T_13680_row0_col1" class="data row0 col1" >419</td>
#       <td id="T_13680_row0_col2" class="data row0 col2" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13680_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13680_row1_col0" class="data row1 col0" >Student Success Center - In Person</td>
#       <td id="T_13680_row1_col1" class="data row1 col1" >305</td>
#       <td id="T_13680_row1_col2" class="data row1 col2" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13680_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13680_row2_col0" class="data row2 col0" >Academic Support Center</td>
#       <td id="T_13680_row2_col1" class="data row2 col1" >108</td>
#       <td id="T_13680_row2_col2" class="data row2 col2" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13680_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13680_row3_col0" class="data row3 col0" >Library 3rd Floor - In Person</td>
#       <td id="T_13680_row3_col1" class="data row3 col1" >79</td>
#       <td id="T_13680_row3_col2" class="data row3 col2" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13680_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13680_row4_col0" class="data row4 col0" >Zoom Meeting Online</td>
#       <td id="T_13680_row4_col1" class="data row4 col1" >58</td>
#       <td id="T_13680_row4_col2" class="data row4 col2" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13680_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13680_row5_col0" class="data row5 col0" >Student Success Center</td>
#       <td id="T_13680_row5_col1" class="data row5 col1" >54</td>
#       <td id="T_13680_row5_col2" class="data row5 col2" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13680_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_13680_row6_col0" class="data row6 col0" >Library - Third Floor</td>
#       <td id="T_13680_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_13680_row6_col2" class="data row6 col2" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13680_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_13680_row7_col0" class="data row7 col0" >Student Success Center - Main Campus</td>
#       <td id="T_13680_row7_col1" class="data row7 col1" >32</td>
#       <td id="T_13680_row7_col2" class="data row7 col2" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13680_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_13680_row8_col0" class="data row8 col0" >CSM 201 - Math Commons</td>
#       <td id="T_13680_row8_col1" class="data row8 col1" >30</td>
#       <td id="T_13680_row8_col2" class="data row8 col2" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13680_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_13680_row9_col0" class="data row9 col0" >Math Lab - In Person</td>
#       <td id="T_13680_row9_col1" class="data row9 col1" >17</td>
#       <td id="T_13680_row9_col2" class="data row9 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Second df - count of total Tutoting sessions by session type

#Calculating count of tutoring sessions by Session Type
All_Cnt_Typ = All_Dates_df.groupby(["Session Type"])["Session Type"].count().reset_index(name="Total Tutoring Sessions").sort_values(by='Total Tutoring Sessions', ascending=False).reset_index(drop=True)

#Calculating percent of total for Session Count by Session Type
All_Cnt_Typ['Session_Pct'] = ((All_Cnt_Typ['Total Tutoring Sessions']/All_Cnt_Typ['Total Tutoring Sessions'].sum())*100).round(0)

#Formatting All_Cnt_Typ
All_Cnt_Typ = All_Cnt_Typ.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

#Total tutoring sessions (for both datasets) by Session Type (Kind) W/ % of total
All_Cnt_Typ
# Out:
# <style type="text/css">
# #T_0a406 th {
#   text-align: left;
# }
# #T_0a406_row0_col0, #T_0a406_row0_col1, #T_0a406_row0_col2, #T_0a406_row1_col0, #T_0a406_row1_col1, #T_0a406_row1_col2, #T_0a406_row2_col0, #T_0a406_row2_col1, #T_0a406_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_0a406">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a406_level0_col0" class="col_heading level0 col0" >Session Type</th>
#       <th id="T_0a406_level0_col1" class="col_heading level0 col1" >Total Tutoring Sessions</th>
#       <th id="T_0a406_level0_col2" class="col_heading level0 col2" >Session_Pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a406_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a406_row0_col0" class="data row0 col0" >Group</td>
#       <td id="T_0a406_row0_col1" class="data row0 col1" >599</td>
#       <td id="T_0a406_row0_col2" class="data row0 col2" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a406_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a406_row1_col0" class="data row1 col0" >Drop-In Tutoring</td>
#       <td id="T_0a406_row1_col1" class="data row1 col1" >388</td>
#       <td id="T_0a406_row1_col2" class="data row1 col2" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a406_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a406_row2_col0" class="data row2 col0" >1-on-1</td>
#       <td id="T_0a406_row2_col1" class="data row2 col1" >292</td>
#       <td id="T_0a406_row2_col2" class="data row2 col2" >23.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Third df - Top 10 Count of drop-in sessions by community and status W/ % of total

#Calculating tutoring session Count grouped by Community Partittion on Status 
df_Cm_Stat = All_Dates_df.groupby(["Community","Status"])["Community"].count().reset_index(name="Total Tutoring sessions").sort_values(by='Total Tutoring sessions', ascending=False).reset_index(drop=True)

#Calculating percent of total for Session Count by Community Partittion on Status 
df_Cm_Stat['Session_Pct'] = ((df_Cm_Stat['Total Tutoring sessions']/df_Cm_Stat['Total Tutoring sessions'].sum())*100).round(0)

#Formatting df_LS
All_Cm_Sat = df_Cm_Stat.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

#Top 10 Count of drop-in sessions by community and status W/ % of total
All_Cm_Sat
# Out:
# <style type="text/css">
# #T_709d1 th {
#   text-align: left;
# }
# #T_709d1_row0_col0, #T_709d1_row0_col1, #T_709d1_row0_col2, #T_709d1_row0_col3, #T_709d1_row1_col0, #T_709d1_row1_col1, #T_709d1_row1_col2, #T_709d1_row1_col3, #T_709d1_row2_col0, #T_709d1_row2_col1, #T_709d1_row2_col2, #T_709d1_row2_col3, #T_709d1_row3_col0, #T_709d1_row3_col1, #T_709d1_row3_col2, #T_709d1_row3_col3, #T_709d1_row4_col0, #T_709d1_row4_col1, #T_709d1_row4_col2, #T_709d1_row4_col3, #T_709d1_row5_col0, #T_709d1_row5_col1, #T_709d1_row5_col2, #T_709d1_row5_col3, #T_709d1_row6_col0, #T_709d1_row6_col1, #T_709d1_row6_col2, #T_709d1_row6_col3, #T_709d1_row7_col0, #T_709d1_row7_col1, #T_709d1_row7_col2, #T_709d1_row7_col3, #T_709d1_row8_col0, #T_709d1_row8_col1, #T_709d1_row8_col2, #T_709d1_row8_col3, #T_709d1_row9_col0, #T_709d1_row9_col1, #T_709d1_row9_col2, #T_709d1_row9_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_709d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_709d1_level0_col0" class="col_heading level0 col0" >Community</th>
#       <th id="T_709d1_level0_col1" class="col_heading level0 col1" >Status</th>
#       <th id="T_709d1_level0_col2" class="col_heading level0 col2" >Total Tutoring sessions</th>
#       <th id="T_709d1_level0_col3" class="col_heading level0 col3" >Session_Pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_709d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_709d1_row0_col0" class="data row0 col0" >Zoom Meeting - Online</td>
#       <td id="T_709d1_row0_col1" class="data row0 col1" >Completed</td>
#       <td id="T_709d1_row0_col2" class="data row0 col2" >265</td>
#       <td id="T_709d1_row0_col3" class="data row0 col3" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_709d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_709d1_row1_col0" class="data row1 col0" >Student Success Center - In Person</td>
#       <td id="T_709d1_row1_col1" class="data row1 col1" >Completed</td>
#       <td id="T_709d1_row1_col2" class="data row1 col2" >211</td>
#       <td id="T_709d1_row1_col3" class="data row1 col3" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_709d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_709d1_row2_col0" class="data row2 col0" >Zoom Meeting - Online</td>
#       <td id="T_709d1_row2_col1" class="data row2 col1" >Cancelled</td>
#       <td id="T_709d1_row2_col2" class="data row2 col2" >140</td>
#       <td id="T_709d1_row2_col3" class="data row2 col3" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_709d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_709d1_row3_col0" class="data row3 col0" >Academic Support Center</td>
#       <td id="T_709d1_row3_col1" class="data row3 col1" >Check In</td>
#       <td id="T_709d1_row3_col2" class="data row3 col2" >108</td>
#       <td id="T_709d1_row3_col3" class="data row3 col3" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_709d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_709d1_row4_col0" class="data row4 col0" >Student Success Center - In Person</td>
#       <td id="T_709d1_row4_col1" class="data row4 col1" >Cancelled</td>
#       <td id="T_709d1_row4_col2" class="data row4 col2" >83</td>
#       <td id="T_709d1_row4_col3" class="data row4 col3" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_709d1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_709d1_row5_col0" class="data row5 col0" >Student Success Center</td>
#       <td id="T_709d1_row5_col1" class="data row5 col1" >Check In</td>
#       <td id="T_709d1_row5_col2" class="data row5 col2" >54</td>
#       <td id="T_709d1_row5_col3" class="data row5 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_709d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_709d1_row6_col0" class="data row6 col0" >Library 3rd Floor - In Person</td>
#       <td id="T_709d1_row6_col1" class="data row6 col1" >Completed</td>
#       <td id="T_709d1_row6_col2" class="data row6 col2" >44</td>
#       <td id="T_709d1_row6_col3" class="data row6 col3" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_709d1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_709d1_row7_col0" class="data row7 col0" >Library 3rd Floor - In Person</td>
#       <td id="T_709d1_row7_col1" class="data row7 col1" >Cancelled</td>
#       <td id="T_709d1_row7_col2" class="data row7 col2" >35</td>
#       <td id="T_709d1_row7_col3" class="data row7 col3" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_709d1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_709d1_row8_col0" class="data row8 col0" >Student Success Center - Main Campus</td>
#       <td id="T_709d1_row8_col1" class="data row8 col1" >Check In</td>
#       <td id="T_709d1_row8_col2" class="data row8 col2" >32</td>
#       <td id="T_709d1_row8_col3" class="data row8 col3" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_709d1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_709d1_row9_col0" class="data row9 col0" >Zoom Meeting Online</td>
#       <td id="T_709d1_row9_col1" class="data row9 col1" >Completed</td>
#       <td id="T_709d1_row9_col2" class="data row9 col2" >31</td>
#       <td id="T_709d1_row9_col3" class="data row9 col3" >2.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fourth df - Top 10 Count of drop-in sessions by community, session type, and status W/ % of total

#Calculating tutoring session Count grouped by Community Partittion on Session Type and Status 
All_Typ_Stat =  All_Dates_df.groupby(["Community","Session Type","Status"])["Community"].count().reset_index(name="Total Tutoring sessions").sort_values(by='Total Tutoring sessions', ascending=False).reset_index(drop=True)

#Calculating percent of total for Session Count by Community Partittion on Session Type and Status 
All_Typ_Stat['Session_Pct'] = ((All_Typ_Stat['Total Tutoring sessions']/All_Typ_Stat['Total Tutoring sessions'].sum())*100).round(0)

#Formatting df_LS
Cnt_Typ_stat = All_Typ_Stat.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

#Top 10 Count of drop-in sessions by community, session type, and status W/ % of total
Cnt_Typ_stat
# Out:
# <style type="text/css">
# #T_23ac7 th {
#   text-align: left;
# }
# #T_23ac7_row0_col0, #T_23ac7_row0_col1, #T_23ac7_row0_col2, #T_23ac7_row0_col3, #T_23ac7_row0_col4, #T_23ac7_row1_col0, #T_23ac7_row1_col1, #T_23ac7_row1_col2, #T_23ac7_row1_col3, #T_23ac7_row1_col4, #T_23ac7_row2_col0, #T_23ac7_row2_col1, #T_23ac7_row2_col2, #T_23ac7_row2_col3, #T_23ac7_row2_col4, #T_23ac7_row3_col0, #T_23ac7_row3_col1, #T_23ac7_row3_col2, #T_23ac7_row3_col3, #T_23ac7_row3_col4, #T_23ac7_row4_col0, #T_23ac7_row4_col1, #T_23ac7_row4_col2, #T_23ac7_row4_col3, #T_23ac7_row4_col4, #T_23ac7_row5_col0, #T_23ac7_row5_col1, #T_23ac7_row5_col2, #T_23ac7_row5_col3, #T_23ac7_row5_col4, #T_23ac7_row6_col0, #T_23ac7_row6_col1, #T_23ac7_row6_col2, #T_23ac7_row6_col3, #T_23ac7_row6_col4, #T_23ac7_row7_col0, #T_23ac7_row7_col1, #T_23ac7_row7_col2, #T_23ac7_row7_col3, #T_23ac7_row7_col4, #T_23ac7_row8_col0, #T_23ac7_row8_col1, #T_23ac7_row8_col2, #T_23ac7_row8_col3, #T_23ac7_row8_col4, #T_23ac7_row9_col0, #T_23ac7_row9_col1, #T_23ac7_row9_col2, #T_23ac7_row9_col3, #T_23ac7_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_23ac7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23ac7_level0_col0" class="col_heading level0 col0" >Community</th>
#       <th id="T_23ac7_level0_col1" class="col_heading level0 col1" >Session Type</th>
#       <th id="T_23ac7_level0_col2" class="col_heading level0 col2" >Status</th>
#       <th id="T_23ac7_level0_col3" class="col_heading level0 col3" >Total Tutoring sessions</th>
#       <th id="T_23ac7_level0_col4" class="col_heading level0 col4" >Session_Pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23ac7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23ac7_row0_col0" class="data row0 col0" >Zoom Meeting - Online</td>
#       <td id="T_23ac7_row0_col1" class="data row0 col1" >Group</td>
#       <td id="T_23ac7_row0_col2" class="data row0 col2" >Completed</td>
#       <td id="T_23ac7_row0_col3" class="data row0 col3" >234</td>
#       <td id="T_23ac7_row0_col4" class="data row0 col4" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23ac7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23ac7_row1_col0" class="data row1 col0" >Student Success Center - In Person</td>
#       <td id="T_23ac7_row1_col1" class="data row1 col1" >Group</td>
#       <td id="T_23ac7_row1_col2" class="data row1 col2" >Completed</td>
#       <td id="T_23ac7_row1_col3" class="data row1 col3" >192</td>
#       <td id="T_23ac7_row1_col4" class="data row1 col4" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23ac7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_23ac7_row2_col0" class="data row2 col0" >Academic Support Center</td>
#       <td id="T_23ac7_row2_col1" class="data row2 col1" >Drop-In Tutoring</td>
#       <td id="T_23ac7_row2_col2" class="data row2 col2" >Check In</td>
#       <td id="T_23ac7_row2_col3" class="data row2 col3" >108</td>
#       <td id="T_23ac7_row2_col4" class="data row2 col4" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23ac7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_23ac7_row3_col0" class="data row3 col0" >Zoom Meeting - Online</td>
#       <td id="T_23ac7_row3_col1" class="data row3 col1" >1-on-1</td>
#       <td id="T_23ac7_row3_col2" class="data row3 col2" >Cancelled</td>
#       <td id="T_23ac7_row3_col3" class="data row3 col3" >73</td>
#       <td id="T_23ac7_row3_col4" class="data row3 col4" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23ac7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_23ac7_row4_col0" class="data row4 col0" >Zoom Meeting - Online</td>
#       <td id="T_23ac7_row4_col1" class="data row4 col1" >Group</td>
#       <td id="T_23ac7_row4_col2" class="data row4 col2" >Cancelled</td>
#       <td id="T_23ac7_row4_col3" class="data row4 col3" >67</td>
#       <td id="T_23ac7_row4_col4" class="data row4 col4" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23ac7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_23ac7_row5_col0" class="data row5 col0" >Student Success Center</td>
#       <td id="T_23ac7_row5_col1" class="data row5 col1" >Drop-In Tutoring</td>
#       <td id="T_23ac7_row5_col2" class="data row5 col2" >Check In</td>
#       <td id="T_23ac7_row5_col3" class="data row5 col3" >54</td>
#       <td id="T_23ac7_row5_col4" class="data row5 col4" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23ac7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_23ac7_row6_col0" class="data row6 col0" >Student Success Center - In Person</td>
#       <td id="T_23ac7_row6_col1" class="data row6 col1" >Group</td>
#       <td id="T_23ac7_row6_col2" class="data row6 col2" >Cancelled</td>
#       <td id="T_23ac7_row6_col3" class="data row6 col3" >48</td>
#       <td id="T_23ac7_row6_col4" class="data row6 col4" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23ac7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_23ac7_row7_col0" class="data row7 col0" >Student Success Center - In Person</td>
#       <td id="T_23ac7_row7_col1" class="data row7 col1" >1-on-1</td>
#       <td id="T_23ac7_row7_col2" class="data row7 col2" >Cancelled</td>
#       <td id="T_23ac7_row7_col3" class="data row7 col3" >35</td>
#       <td id="T_23ac7_row7_col4" class="data row7 col4" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23ac7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_23ac7_row8_col0" class="data row8 col0" >Student Success Center - Main Campus</td>
#       <td id="T_23ac7_row8_col1" class="data row8 col1" >Drop-In Tutoring</td>
#       <td id="T_23ac7_row8_col2" class="data row8 col2" >Check In</td>
#       <td id="T_23ac7_row8_col3" class="data row8 col3" >32</td>
#       <td id="T_23ac7_row8_col4" class="data row8 col4" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23ac7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_23ac7_row9_col0" class="data row9 col0" >Zoom Meeting - Online</td>
#       <td id="T_23ac7_row9_col1" class="data row9 col1" >1-on-1</td>
#       <td id="T_23ac7_row9_col2" class="data row9 col2" >Completed</td>
#       <td id="T_23ac7_row9_col3" class="data row9 col3" >31</td>
#       <td id="T_23ac7_row9_col4" class="data row9 col4" >2.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Fifth df - Total count of completed tutoring sessions  grouped by status, year, and month W/ % of total

# Count of total tutoring sesions grouped by status, month, and year
df_Mth_Cnt = All_Dates_df.groupby(["Started_At_Year","Started_At_Month","Status"])["Status"].count().reset_index(name="Total Appointments").sort_values(['Started_At_Year','Started_At_Month']).reset_index(drop=True).round({'Started_At_Year': 0, 'Started_At_Month': 0})

#Formatting df_Typ_St filtering Count of total tutoring sesions by "completed" status
df_Mth_Cnt_Cmplt = df_Mth_Cnt[df_Mth_Cnt.Status == "Completed"].reset_index(drop=True).round({'Started_At_Year':0, 'Started_At_Month': 0}).style.set_properties(**{'text-align': 'left'}).set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

#Total count of completed tutoring sessions grouped by date and status W/ % of total
df_Mth_Cnt_Cmplt
# Out:
# <style type="text/css">
# #T_c6cdb th {
#   text-align: left;
# }
# #T_c6cdb_row0_col0, #T_c6cdb_row0_col1, #T_c6cdb_row0_col2, #T_c6cdb_row0_col3, #T_c6cdb_row1_col0, #T_c6cdb_row1_col1, #T_c6cdb_row1_col2, #T_c6cdb_row1_col3, #T_c6cdb_row2_col0, #T_c6cdb_row2_col1, #T_c6cdb_row2_col2, #T_c6cdb_row2_col3, #T_c6cdb_row3_col0, #T_c6cdb_row3_col1, #T_c6cdb_row3_col2, #T_c6cdb_row3_col3, #T_c6cdb_row4_col0, #T_c6cdb_row4_col1, #T_c6cdb_row4_col2, #T_c6cdb_row4_col3, #T_c6cdb_row5_col0, #T_c6cdb_row5_col1, #T_c6cdb_row5_col2, #T_c6cdb_row5_col3, #T_c6cdb_row6_col0, #T_c6cdb_row6_col1, #T_c6cdb_row6_col2, #T_c6cdb_row6_col3, #T_c6cdb_row7_col0, #T_c6cdb_row7_col1, #T_c6cdb_row7_col2, #T_c6cdb_row7_col3, #T_c6cdb_row8_col0, #T_c6cdb_row8_col1, #T_c6cdb_row8_col2, #T_c6cdb_row8_col3, #T_c6cdb_row9_col0, #T_c6cdb_row9_col1, #T_c6cdb_row9_col2, #T_c6cdb_row9_col3, #T_c6cdb_row10_col0, #T_c6cdb_row10_col1, #T_c6cdb_row10_col2, #T_c6cdb_row10_col3, #T_c6cdb_row11_col0, #T_c6cdb_row11_col1, #T_c6cdb_row11_col2, #T_c6cdb_row11_col3, #T_c6cdb_row12_col0, #T_c6cdb_row12_col1, #T_c6cdb_row12_col2, #T_c6cdb_row12_col3, #T_c6cdb_row13_col0, #T_c6cdb_row13_col1, #T_c6cdb_row13_col2, #T_c6cdb_row13_col3, #T_c6cdb_row14_col0, #T_c6cdb_row14_col1, #T_c6cdb_row14_col2, #T_c6cdb_row14_col3, #T_c6cdb_row15_col0, #T_c6cdb_row15_col1, #T_c6cdb_row15_col2, #T_c6cdb_row15_col3, #T_c6cdb_row16_col0, #T_c6cdb_row16_col1, #T_c6cdb_row16_col2, #T_c6cdb_row16_col3, #T_c6cdb_row17_col0, #T_c6cdb_row17_col1, #T_c6cdb_row17_col2, #T_c6cdb_row17_col3, #T_c6cdb_row18_col0, #T_c6cdb_row18_col1, #T_c6cdb_row18_col2, #T_c6cdb_row18_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_c6cdb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6cdb_level0_col0" class="col_heading level0 col0" >Started_At_Year</th>
#       <th id="T_c6cdb_level0_col1" class="col_heading level0 col1" >Started_At_Month</th>
#       <th id="T_c6cdb_level0_col2" class="col_heading level0 col2" >Status</th>
#       <th id="T_c6cdb_level0_col3" class="col_heading level0 col3" >Total Appointments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6cdb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6cdb_row0_col0" class="data row0 col0" >2021.000000</td>
#       <td id="T_c6cdb_row0_col1" class="data row0 col1" >6.000000</td>
#       <td id="T_c6cdb_row0_col2" class="data row0 col2" >Completed</td>
#       <td id="T_c6cdb_row0_col3" class="data row0 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6cdb_row1_col0" class="data row1 col0" >2021.000000</td>
#       <td id="T_c6cdb_row1_col1" class="data row1 col1" >7.000000</td>
#       <td id="T_c6cdb_row1_col2" class="data row1 col2" >Completed</td>
#       <td id="T_c6cdb_row1_col3" class="data row1 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c6cdb_row2_col0" class="data row2 col0" >2021.000000</td>
#       <td id="T_c6cdb_row2_col1" class="data row2 col1" >8.000000</td>
#       <td id="T_c6cdb_row2_col2" class="data row2 col2" >Completed</td>
#       <td id="T_c6cdb_row2_col3" class="data row2 col3" >56</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c6cdb_row3_col0" class="data row3 col0" >2021.000000</td>
#       <td id="T_c6cdb_row3_col1" class="data row3 col1" >9.000000</td>
#       <td id="T_c6cdb_row3_col2" class="data row3 col2" >Completed</td>
#       <td id="T_c6cdb_row3_col3" class="data row3 col3" >87</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c6cdb_row4_col0" class="data row4 col0" >2021.000000</td>
#       <td id="T_c6cdb_row4_col1" class="data row4 col1" >10.000000</td>
#       <td id="T_c6cdb_row4_col2" class="data row4 col2" >Completed</td>
#       <td id="T_c6cdb_row4_col3" class="data row4 col3" >136</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c6cdb_row5_col0" class="data row5 col0" >2021.000000</td>
#       <td id="T_c6cdb_row5_col1" class="data row5 col1" >11.000000</td>
#       <td id="T_c6cdb_row5_col2" class="data row5 col2" >Completed</td>
#       <td id="T_c6cdb_row5_col3" class="data row5 col3" >92</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c6cdb_row6_col0" class="data row6 col0" >2021.000000</td>
#       <td id="T_c6cdb_row6_col1" class="data row6 col1" >12.000000</td>
#       <td id="T_c6cdb_row6_col2" class="data row6 col2" >Completed</td>
#       <td id="T_c6cdb_row6_col3" class="data row6 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c6cdb_row7_col0" class="data row7 col0" >2022.000000</td>
#       <td id="T_c6cdb_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_c6cdb_row7_col2" class="data row7 col2" >Completed</td>
#       <td id="T_c6cdb_row7_col3" class="data row7 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c6cdb_row8_col0" class="data row8 col0" >2022.000000</td>
#       <td id="T_c6cdb_row8_col1" class="data row8 col1" >2.000000</td>
#       <td id="T_c6cdb_row8_col2" class="data row8 col2" >Completed</td>
#       <td id="T_c6cdb_row8_col3" class="data row8 col3" >36</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c6cdb_row9_col0" class="data row9 col0" >2022.000000</td>
#       <td id="T_c6cdb_row9_col1" class="data row9 col1" >3.000000</td>
#       <td id="T_c6cdb_row9_col2" class="data row9 col2" >Completed</td>
#       <td id="T_c6cdb_row9_col3" class="data row9 col3" >53</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c6cdb_row10_col0" class="data row10 col0" >2022.000000</td>
#       <td id="T_c6cdb_row10_col1" class="data row10 col1" >4.000000</td>
#       <td id="T_c6cdb_row10_col2" class="data row10 col2" >Completed</td>
#       <td id="T_c6cdb_row10_col3" class="data row10 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c6cdb_row11_col0" class="data row11 col0" >2022.000000</td>
#       <td id="T_c6cdb_row11_col1" class="data row11 col1" >5.000000</td>
#       <td id="T_c6cdb_row11_col2" class="data row11 col2" >Completed</td>
#       <td id="T_c6cdb_row11_col3" class="data row11 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c6cdb_row12_col0" class="data row12 col0" >2022.000000</td>
#       <td id="T_c6cdb_row12_col1" class="data row12 col1" >6.000000</td>
#       <td id="T_c6cdb_row12_col2" class="data row12 col2" >Completed</td>
#       <td id="T_c6cdb_row12_col3" class="data row12 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c6cdb_row13_col0" class="data row13 col0" >2022.000000</td>
#       <td id="T_c6cdb_row13_col1" class="data row13 col1" >7.000000</td>
#       <td id="T_c6cdb_row13_col2" class="data row13 col2" >Completed</td>
#       <td id="T_c6cdb_row13_col3" class="data row13 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c6cdb_row14_col0" class="data row14 col0" >2022.000000</td>
#       <td id="T_c6cdb_row14_col1" class="data row14 col1" >8.000000</td>
#       <td id="T_c6cdb_row14_col2" class="data row14 col2" >Completed</td>
#       <td id="T_c6cdb_row14_col3" class="data row14 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_c6cdb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c6cdb_row15_col0" class="data row15 col0" >2022.000000</td>
#       <td id="T_c6cdb_row15_

# %%
#Sixth df - Total count of Check-in tutoring sessions grouped by status, year, and month W/ % of total

#Formatting df_Typ_St and filtering Count of total tutoring sesions by "Check in" status
df_Mth_Cnt_Chk = df_Mth_Cnt[df_Mth_Cnt.Status == "Check In"].reset_index(drop=True).round({'Started_At_Year':0, 'Started_At_Month': 0}).style.set_properties(**{'text-align': 'left'}).set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

df_Mth_Cnt_Chk
# Out:
# <style type="text/css">
# #T_36f1b th {
#   text-align: left;
# }
# #T_36f1b_row0_col0, #T_36f1b_row0_col1, #T_36f1b_row0_col2, #T_36f1b_row0_col3, #T_36f1b_row1_col0, #T_36f1b_row1_col1, #T_36f1b_row1_col2, #T_36f1b_row1_col3, #T_36f1b_row2_col0, #T_36f1b_row2_col1, #T_36f1b_row2_col2, #T_36f1b_row2_col3, #T_36f1b_row3_col0, #T_36f1b_row3_col1, #T_36f1b_row3_col2, #T_36f1b_row3_col3, #T_36f1b_row4_col0, #T_36f1b_row4_col1, #T_36f1b_row4_col2, #T_36f1b_row4_col3, #T_36f1b_row5_col0, #T_36f1b_row5_col1, #T_36f1b_row5_col2, #T_36f1b_row5_col3, #T_36f1b_row6_col0, #T_36f1b_row6_col1, #T_36f1b_row6_col2, #T_36f1b_row6_col3, #T_36f1b_row7_col0, #T_36f1b_row7_col1, #T_36f1b_row7_col2, #T_36f1b_row7_col3, #T_36f1b_row8_col0, #T_36f1b_row8_col1, #T_36f1b_row8_col2, #T_36f1b_row8_col3, #T_36f1b_row9_col0, #T_36f1b_row9_col1, #T_36f1b_row9_col2, #T_36f1b_row9_col3, #T_36f1b_row10_col0, #T_36f1b_row10_col1, #T_36f1b_row10_col2, #T_36f1b_row10_col3, #T_36f1b_row11_col0, #T_36f1b_row11_col1, #T_36f1b_row11_col2, #T_36f1b_row11_col3, #T_36f1b_row12_col0, #T_36f1b_row12_col1, #T_36f1b_row12_col2, #T_36f1b_row12_col3, #T_36f1b_row13_col0, #T_36f1b_row13_col1, #T_36f1b_row13_col2, #T_36f1b_row13_col3, #T_36f1b_row14_col0, #T_36f1b_row14_col1, #T_36f1b_row14_col2, #T_36f1b_row14_col3, #T_36f1b_row15_col0, #T_36f1b_row15_col1, #T_36f1b_row15_col2, #T_36f1b_row15_col3, #T_36f1b_row16_col0, #T_36f1b_row16_col1, #T_36f1b_row16_col2, #T_36f1b_row16_col3, #T_36f1b_row17_col0, #T_36f1b_row17_col1, #T_36f1b_row17_col2, #T_36f1b_row17_col3, #T_36f1b_row18_col0, #T_36f1b_row18_col1, #T_36f1b_row18_col2, #T_36f1b_row18_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_36f1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36f1b_level0_col0" class="col_heading level0 col0" >Started_At_Year</th>
#       <th id="T_36f1b_level0_col1" class="col_heading level0 col1" >Started_At_Month</th>
#       <th id="T_36f1b_level0_col2" class="col_heading level0 col2" >Status</th>
#       <th id="T_36f1b_level0_col3" class="col_heading level0 col3" >Total Appointments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36f1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36f1b_row0_col0" class="data row0 col0" >2021.000000</td>
#       <td id="T_36f1b_row0_col1" class="data row0 col1" >6.000000</td>
#       <td id="T_36f1b_row0_col2" class="data row0 col2" >Check In</td>
#       <td id="T_36f1b_row0_col3" class="data row0 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36f1b_row1_col0" class="data row1 col0" >2021.000000</td>
#       <td id="T_36f1b_row1_col1" class="data row1 col1" >7.000000</td>
#       <td id="T_36f1b_row1_col2" class="data row1 col2" >Check In</td>
#       <td id="T_36f1b_row1_col3" class="data row1 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_36f1b_row2_col0" class="data row2 col0" >2021.000000</td>
#       <td id="T_36f1b_row2_col1" class="data row2 col1" >8.000000</td>
#       <td id="T_36f1b_row2_col2" class="data row2 col2" >Check In</td>
#       <td id="T_36f1b_row2_col3" class="data row2 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_36f1b_row3_col0" class="data row3 col0" >2021.000000</td>
#       <td id="T_36f1b_row3_col1" class="data row3 col1" >9.000000</td>
#       <td id="T_36f1b_row3_col2" class="data row3 col2" >Check In</td>
#       <td id="T_36f1b_row3_col3" class="data row3 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_36f1b_row4_col0" class="data row4 col0" >2021.000000</td>
#       <td id="T_36f1b_row4_col1" class="data row4 col1" >10.000000</td>
#       <td id="T_36f1b_row4_col2" class="data row4 col2" >Check In</td>
#       <td id="T_36f1b_row4_col3" class="data row4 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_36f1b_row5_col0" class="data row5 col0" >2021.000000</td>
#       <td id="T_36f1b_row5_col1" class="data row5 col1" >11.000000</td>
#       <td id="T_36f1b_row5_col2" class="data row5 col2" >Check In</td>
#       <td id="T_36f1b_row5_col3" class="data row5 col3" >27</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_36f1b_row6_col0" class="data row6 col0" >2021.000000</td>
#       <td id="T_36f1b_row6_col1" class="data row6 col1" >12.000000</td>
#       <td id="T_36f1b_row6_col2" class="data row6 col2" >Check In</td>
#       <td id="T_36f1b_row6_col3" class="data row6 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_36f1b_row7_col0" class="data row7 col0" >2022.000000</td>
#       <td id="T_36f1b_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_36f1b_row7_col2" class="data row7 col2" >Check In</td>
#       <td id="T_36f1b_row7_col3" class="data row7 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_36f1b_row8_col0" class="data row8 col0" >2022.000000</td>
#       <td id="T_36f1b_row8_col1" class="data row8 col1" >2.000000</td>
#       <td id="T_36f1b_row8_col2" class="data row8 col2" >Check In</td>
#       <td id="T_36f1b_row8_col3" class="data row8 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_36f1b_row9_col0" class="data row9 col0" >2022.000000</td>
#       <td id="T_36f1b_row9_col1" class="data row9 col1" >3.000000</td>
#       <td id="T_36f1b_row9_col2" class="data row9 col2" >Check In</td>
#       <td id="T_36f1b_row9_col3" class="data row9 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_36f1b_row10_col0" class="data row10 col0" >2022.000000</td>
#       <td id="T_36f1b_row10_col1" class="data row10 col1" >4.000000</td>
#       <td id="T_36f1b_row10_col2" class="data row10 col2" >Check In</td>
#       <td id="T_36f1b_row10_col3" class="data row10 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_36f1b_row11_col0" class="data row11 col0" >2022.000000</td>
#       <td id="T_36f1b_row11_col1" class="data row11 col1" >5.000000</td>
#       <td id="T_36f1b_row11_col2" class="data row11 col2" >Check In</td>
#       <td id="T_36f1b_row11_col3" class="data row11 col3" >28</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_36f1b_row12_col0" class="data row12 col0" >2022.000000</td>
#       <td id="T_36f1b_row12_col1" class="data row12 col1" >6.000000</td>
#       <td id="T_36f1b_row12_col2" class="data row12 col2" >Check In</td>
#       <td id="T_36f1b_row12_col3" class="data row12 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_36f1b_row13_col0" class="data row13 col0" >2022.000000</td>
#       <td id="T_36f1b_row13_col1" class="data row13 col1" >7.000000</td>
#       <td id="T_36f1b_row13_col2" class="data row13 col2" >Check In</td>
#       <td id="T_36f1b_row13_col3" class="data row13 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_36f1b_row14_col0" class="data row14 col0" >2022.000000</td>
#       <td id="T_36f1b_row14_col1" class="data row14 col1" >8.000000</td>
#       <td id="T_36f1b_row14_col2" class="data row14 col2" >Check In</td>
#       <td id="T_36f1b_row14_col3" class="data row14 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_36f1b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_36f1b_row15_col0" class="data row15 col0" >2022.000000</td>
#       <td id="T_36f1b_row15_col1" class="d
